# %%
#DAY2: VARIABLES AND BUILT-IN FUNCTIONS

# %%
#Q1 
first_name="Lesego"
last_name="Mongalo"
full_name="Lesego Mongalo"
country="South Africa"
city="Johannesburg"
age=21
year=2026
is_married=False
is_true=True
is_light_on=False
x,y,z=1,2,30

# %%
print(first_name)
print(last_name)
print(full_name)
print(country)
print(city)
print(age)
print(year)
print(is_married)
print(is_true)
print(is_light_on)
print(x,y,z)
# Out:
# Lesego
# Mongalo
# Lesego Mongalo
# South Africa
# Johannesburg
# 21
# 2026
# False
# True
# False
# 1 2 30

# %%
#Q2
len(first_name)
# Out:
# 6

# %%
len(last_name)
# Out:
# 7

# %%
#Q3
print(len(first_name)==len(last_name))
print(len(first_name)!=len(last_name))
print(len(first_name)<len(last_name))
print(len(first_name)>len(last_name))
# Out:
# False
# True
# True
# False

# %%
#Q4
num_one=5
num_two=4

# %%
#Q5
total=num_one + num_two
total
# Out:
# 9

# %%
#Q6
diff=num_one - num_two
diff
# Out:
# 1

# %%
#Q7
product=num_one * num_two
product
# Out:
# 20

# %%
#Q8
division=num_one / num_two
division
# Out:
# 1.25

# %%
#Q9
remainder=num_one % num_two
remainder
# Out:
# 1

# %%
#Q10
exp=num_one ** num_two
exp
# Out:
# 625

# %%
#Q11
floor_division=num_one // num_two
floor_division
# Out:
# 1

# %%
#Q12
radius=30
import math
math.pi

area=math.pi*(radius**2)
print("Area of a circle:",area)
# Out:
# Area of a circle: 2827.4333882308138

# %%
#Q13

first_name=input("enter your first name: ")
last_name=input("enter your last name: ")
country=input("enter your country: ")
age=input("enter your age: ")
# Out:
# enter your first name:  Lesego
# enter your last name:  Mongalo
# enter your country:  South Africa
# enter your age:  21

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

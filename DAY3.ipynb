# %%
#Q1
age=21

# %%
#Q2
height=1.73

# %%
complex_number=(2+3j)

# %%
#Q4
base=float(input("enter base:"))
height=float(input("enter height:"))
area=0.5*base*height
print("The Area is:",area)
# Out:
# enter base: 20
# enter height: 10
# The Area is: 100.0

# %%
#Q5
a=float(input("side a:"))
b=float(input("side b:"))
c=float(input("side c:"))
perimeter=a+b+c
print("The perimeter of the triangle is:",perimeter)
# Out:
# side a: 5
# side b: 4
# side c: 3
# The perimeter of the triangle is: 12.0

# %%
#Q6
length=float(input("length:"))
width=float(input("width:"))
area=length*width
perimeter=2*(length+width)
print("The area is:",area)
print("The perimeter is:",perimeter)
# Out:
# length: 10
# width: 5
# The area is: 50.0
# The perimeter is: 30.0

# %%
#Q7
import math 
radius=float(input("Radius:"))
area=math.pi*radius*radius
circumference=2*math.pi*radius
print("The area:",area)
print("The circumference:",circumference)
# Out:
# Radius: 5
# The area: 78.53981633974483
# The circumference: 31.41592653589793

# %%
#Q8
m=2
x_intercept=1
y_intercept=-2

# %%
#Q9
import math
x1=2
y1=2

x2=6
y2=10

m=(y2-y1)/(x2-x1)
d=math.sqrt((x2-x1)**2 + (y2-y1)**2)

print(m)
print(d)
# Out:
# 2.0
# 8.94427190999916

# %%
#Q11
x=float(input("x:"))
y=x**2 + 6*x + 9
print("y is",y)
# Out:
# x: 3
# y is 36.0

# %%
a=print(len('python'))
b=print(len('dragon'))
a!=b
# Out:
# 6
# 6
# False

# %%
a='python'
b='dragon'
print('on' in a and 'on' in b)
# Out:
# True

# %%
sentence="I hope this course is not full of jargon"

print("jargon" in sentence)
# Out:
# True

# %%
print(len("python"))
print(float(len("python")))
print(str(float(len("python"))))
# Out:
# 6
# 6.0
# 6.0

# %%
number=int(input("input number:"))
print("Is number even:",number%2==0)
# Out:
# input number: 4
# Is number even: True

# %%
7//3==int(2.7)
# Out:
# True

# %%
type('10')== type(10)
# Out:
# False

# %%
hours=int(input("hours:"))
rate=int(input("rate per hoiur:"))
total=hours*rate
print("Your weekly earnings is:",total)
# Out:
# hours: 40
# rate per hoiur: 28
# Your weekly earnings is: 1120

# %%
years=int(input("number of years:"))
a_year=31536000
lived=a_year*years
print("You have lived for",lived,"seconds")
# Out:
# number of years: 21
# You have lived for 662256000 seconds

# %%
for i in (1,2,3,4,5,6):
    print(i,1,i,i**2,i**3)
# Out:
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125
# 6 1 6 36 216
